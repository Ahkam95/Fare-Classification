# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

from sklearn import preprocessing

# %%
train = pd.read_csv('train.csv')
test = pd.read_csv('test.csv')
train
# Out:
#           tripid  additional_fare  duration  meter_waiting  \
# 0      189123628             10.5     834.0           56.0
# 1      189125358             10.5     791.0           47.0
# 2      189125719             10.5    1087.0           80.0
# 3      189127273             10.5     598.0          271.0
# 4      189128020              NaN       NaN            NaN
# 5      189129552             10.5    3407.0          182.0
# 6      189132829             10.5    1246.0          487.0
# 7      189135103             10.5    1333.0          295.0
# 8      189139296             10.5     360.0           80.0
# 9      189138671             10.5    1539.0          588.0
# 10     189135814             10.5      26.0           19.0
# 11     189140969             10.5      31.0           20.0
# 12     189144528             10.5    2011.0          199.0
# 13     189147041             10.5    1260.0           30.0
# 14     189145904             10.5     335.0           10.0
# ...

# %% [markdown]
# ### Filling NaN data with mean value of the columns

# %%
sns.heatmap(train.isnull(),yticklabels=False,cbar=False,cmap='viridis')

# %%
train= train.fillna(train.mean())
sns.heatmap(train.isnull(),yticklabels=False,cbar=False,cmap='viridis')

# %%
train['pickup_time']= pd.to_datetime(train['pickup_time'],format='%m/%d/%Y %H:%M')
train['drop_time']= pd.to_datetime(train['drop_time'],format='%m/%d/%Y %H:%M')

train['day']=train['pickup_time'].dt.day
train['pickup_hour']=train['pickup_time'].dt.hour
train['pickup_minute']=train['pickup_time'].dt.minute

train['drop_hour']=train['drop_time'].dt.hour
train['drop_minute']=train['drop_time'].dt.minute

# %%
train['year']=train['pickup_time'].dt.year 
train['month']=train['pickup_time'].dt.month 
#train['dayofweek_name']=train['pickup_time'].dt.weekday_name

# %%
train.head()
# Out:
#       tripid  additional_fare  duration  meter_waiting  meter_waiting_fare  \
# 0  189123628             10.5     834.0           56.0              0.0000
# 1  189125358             10.5     791.0           47.0              0.0000
# 2  189125719             10.5    1087.0           80.0              0.0000
# 3  189127273             10.5     598.0          271.0             15.6638
# 4  189128020              NaN       NaN            NaN                 NaN
#
#    meter_waiting_till_pickup         pickup_time           drop_time  \
# 0                       64.0 2019-11-01 00:20:00 2019-11-01 00:34:00
# 1                      134.0 2019-11-01 00:56:00 2019-11-01 01:09:00
# 2                       61.0 2019-11-01 01:08:00 2019-11-01 01:26:00
# 3                       68.0 2019-11-01 02:27:00 2019-11-01 02:37:00
# 4                        NaN 2019-11-01 03:34:00 2019-11-01 03:51:00
#
#    pick_lat  pick_lon  ...    drop_lon    fare    label day  pickup_hour  \
# ...

# %%
# train['pickup_time'] = pd.to_datetime(train.pickup_time)
# train['drop_time'] = pd.to_datetime(train.drop_time)
train.drop(['pickup_time', 'drop_time'], axis = 1,inplace = True)

# %%
# train['pickup_time']= pd.to_numeric(train['pickup_time'])
# train['drop_time']= pd.to_numeric(train['drop_time'])

# %%
le = preprocessing.LabelEncoder()
train['label'] = le.fit_transform(train['label'])
train
# Out:
#           tripid  additional_fare     duration  meter_waiting  \
# 0      189123628        10.500000   834.000000      56.000000
# 1      189125358        10.500000   791.000000      47.000000
# 2      189125719        10.500000  1087.000000      80.000000
# 3      189127273        10.500000   598.000000     271.000000
# 4      189128020        13.719651  1702.858077     629.074231
# 5      189129552        10.500000  3407.000000     182.000000
# 6      189132829        10.500000  1246.000000     487.000000
# 7      189135103        10.500000  1333.000000     295.000000
# 8      189139296        10.500000   360.000000      80.000000
# 9      189138671        10.500000  1539.000000     588.000000
# 10     189135814        10.500000    26.000000      19.000000
# 11     189140969        10.500000    31.000000      20.000000
# 12     189144528        10.500000  2011.000000     199.000000
# 13     189147041        10.500000  1260.000000      30.000000
# ...

# %%
train['label'] = pd.to_numeric(train['label'], errors='ignore')
train['label']= 1-train['label']
train.head()
# Out:
#       tripid  additional_fare     duration  meter_waiting  meter_waiting_fare  \
# 0  189123628        10.500000   834.000000      56.000000            0.000000
# 1  189125358        10.500000   791.000000      47.000000            0.000000
# 2  189125719        10.500000  1087.000000      80.000000            0.000000
# 3  189127273        10.500000   598.000000     271.000000           15.663800
# 4  189128020        13.719651  1702.858077     629.074231           32.057666
#
#    meter_waiting_till_pickup  pick_lat  pick_lon  drop_lat  drop_lon    fare  \
# 0                  64.000000   6.86252   79.8993   6.90330   79.8783  270.32
# 1                 134.000000   6.88589   79.8984   6.91373   79.8923  197.85
# 2                  61.000000   6.90839   79.8651   6.93669   79.9146  301.64
# 3                  68.000000   6.92570   79.8895   6.92748   79.8971   82.30
# 4                 112.466832   6.87441   79.8615   6.84478   79.9290  358.39
#
# ...

# %%
train.corr()['label']
# Out:
# tripid                       0.062490
# additional_fare             -0.039219
# duration                    -0.108287
# meter_waiting               -0.102833
# meter_waiting_fare          -0.099049
# meter_waiting_till_pickup   -0.033860
# pick_lat                    -0.029237
# pick_lon                    -0.037713
# drop_lat                    -0.012781
# drop_lon                    -0.030347
# fare                        -0.176411
# label                        1.000000
# day                         -0.015230
# pickup_hour                 -0.004822
# pickup_minute               -0.004256
# drop_hour                   -0.003501
# drop_minute                 -0.000533
# year                         0.042666
# month                       -0.037094
# Name: label, dtype: float64

# %%
# train['additional_fare_band'] = pd.cut(train['duration'], 3)
# train[['additional_fare_band', 'label']].groupby(['additional_fare_band'], as_index=False).mean().sort_values(by='additional_fare_band', ascending=True)

# %%
# combine = [train, test]
# for dataset in combine:    
#     dataset.loc[ dataset['duration'] <= 90774, 'duration'] = 0
#     dataset.loc[(dataset['duration'] > 90774.4) & (dataset['duration'] <= 181548.8), 'duration'] = 1
#     dataset.loc[(dataset['duration'] > 181548.8) & (dataset['duration'] <= 272323.2), 'duration'] = 2
#     dataset.loc[(dataset['duration'] > 272323.2) & (dataset['duration'] <= 363097.6), 'duration'] = 3
#     dataset.loc[ dataset['duration'] > 363097.6, 'duration']
# train.head()

# %%
#train.drop(['additional_fare_band'], axis = 1, inplace= True)

# %%
combine = [train, test]
for data in combine:
    data['pick_lat'] = (data['pick_lat'] - data['pick_lat'].min()) / (data['pick_lat'].max() - data['pick_lat'].min())
    data['pick_lon'] = (data['pick_lon'] - data['pick_lon'].min()) / (data['pick_lon'].max() - data['pick_lon'].min())
    data['drop_lat'] = (data['drop_lat'] - data['drop_lat'].min()) / (data['drop_lat'].max() - data['drop_lat'].min())
    data['drop_lon'] = (data['drop_lon'] - data['drop_lon'].min()) / (data['drop_lon'].max() - data['drop_lon'].min())
    #dataset['meter_waiting_till_pickup'] = (dataset['meter_waiting_till_pickup'] - dataset['meter_waiting_till_pickup'].min()) / (dataset['meter_waiting_till_pickup'].max() - dataset['meter_waiting_till_pickup'].min())
    #dataset['pickup_time'] = (dataset['pickup_time'] - dataset['pickup_time'].min()) / (dataset['pickup_time'].max() - dataset['pickup_time'].min())
    #dataset['drop_time'] = (dataset['drop_time'] - dataset['drop_time'].min()) / (dataset['drop_time'].max() - dataset['drop_time'].min())

# %%
train
# Out:
#           tripid  duration  meter_waiting  meter_waiting_fare  \
# 0      189123628  0.001838       0.000123            0.000000
# 1      189125358  0.001743       0.000104            0.000000
# 2      189125719  0.002395       0.000176            0.000000
# 3      189127273  0.001318       0.000597           15.663800
# 4      189128020  0.003752       0.001387           32.057666
# 5      189129552  0.007507       0.000401            0.000000
# 6      189132829  0.002745       0.001074            0.000000
# 7      189135103  0.002937       0.000650           17.198500
# 8      189139296  0.000793       0.000176            4.664000
# 9      189138671  0.003391       0.001296           33.986400
# 10     189135814  0.000057       0.000042            0.000000
# 11     189140969  0.000068       0.000044            0.000000
# 12     189144528  0.004431       0.000439            0.000000
# 13     189147041  0.002776       0.000066            0.000000
# ...

# %%
train['fare']= train['additional_fare'] + train['fare']
train.drop(['additional_fare'], axis = 1, inplace= True)
train['fare'] = (train['fare'] - train['fare'].min()) / (train['fare'].max() - train['fare'].min())
train['duration'] = (train['duration'] - train['duration'].min()) / (train['duration'].max() - train['duration'].min())
train['meter_waiting'] = (train['meter_waiting'] - train['meter_waiting'].min()) / (train['meter_waiting'].max() - train['meter_waiting'].min())
train['meter_waiting_till_pickup'] = (train['meter_waiting_till_pickup'] - train['meter_waiting_till_pickup'].min()) / (train['meter_waiting_till_pickup'].max() - train['meter_waiting_till_pickup'].min())

# %% [markdown]
# ###test data

# %%
sns.heatmap(test.isnull(),yticklabels=False,cbar=False,cmap='viridis')

# %%
test['pickup_time']= pd.to_datetime(test['pickup_time'],format='%m/%d/%Y %H:%M')
test['drop_time']= pd.to_datetime(test['drop_time'],format='%m/%d/%Y %H:%M')

test['day']=test['pickup_time'].dt.day
test['pickup_hour']=test['pickup_time'].dt.hour
test['pickup_minute']=test['pickup_time'].dt.minute

test['drop_hour']=test['drop_time'].dt.hour
test['drop_minute']=test['drop_time'].dt.minute

# %%
test['year']=test['pickup_time'].dt.year 
test['month']=test['pickup_time'].dt.month

# %%
# test['pickup_time'] = pd.to_datetime(test.pickup_time)
# test['drop_time'] = pd.to_datetime(test.drop_time)

# %%
# test['pickup_time']=pd.to_numeric(test['pickup_time'])
# test['drop_time']=pd.to_numeric(test['drop_time'])

# %%
test.drop(['pickup_time', 'drop_time'], axis = 1,inplace = True)

# %%
test['fare']= test['additional_fare'] + test['fare']
test.drop(['additional_fare'], axis = 1, inplace= True)
test['fare'] = (test['fare'] - test['fare'].min()) / (test['fare'].max() - test['fare'].min())
test['duration'] = (test['duration'] - test['duration'].min()) / (test['duration'].max() - test['duration'].min())
test['meter_waiting'] = (test['meter_waiting'] - test['meter_waiting'].min()) / (test['meter_waiting'].max() - test['meter_waiting'].min())
test['meter_waiting_till_pickup'] = (test['meter_waiting_till_pickup'] - test['meter_waiting_till_pickup'].min()) / (test['meter_waiting_till_pickup'].max() - test['meter_waiting_till_pickup'].min())

# %% [markdown]
# ### selecting X , Y

# %%
X_train = train.drop(['label','tripid'],axis=1)
Y_train = train['label']
X_test= test.drop(['tripid'],axis=1)

# %% [markdown]
# ### Xgboost model building

# %%
import xgboost as xgb
# model=xgb.XGBClassifier(silent=False, 
#                       scale_pos_weight=1,
#                       learning_rate=0.01,  
#                       colsample_bytree = 0.4,
#                       subsample = 0.8,
#                       objective='binary:logistic', 
#                       n_estimators=1000, 
#                       reg_alpha = 0.3,
#                       max_depth=4, 
#                       gamma=1)

model=xgb.XGBClassifier()
model.fit(X_train, Y_train)
#model.score(x_test,y_test)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\dask\config.py:161: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   data = yaml.load(f.read()) or {}
# XGBClassifier(base_score=0.5, booster=None, colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, gamma=0, gpu_id=-1,
#               importance_type='gain', interaction_constraints=None,
#               learning_rate=0.300000012, max_delta_step=0, max_depth=6,
#               min_child_weight=1, missing=nan, monotone_constraints=None,
#               n_estimators=100, n_jobs=0, num_parallel_tree=1,
#               objective='binary:logistic', random_state=0, reg_alpha=0,
#               reg_lambda=1, scale_pos_weight=1, subsample=1, tree_method=None,
#               validate_parameters=False, verbosity=None)

# %%
y_pred = model.predict(X_test)

# %%
prediction_output = pd.DataFrame(test['tripid'])

# %%
prediction_output['prediction']= y_pred

# %%
prediction_output.to_csv('xgboost_14_3.csv', encoding='utf-8', index=False)

# %% [markdown]
# ### Grid search

# %%
from sklearn.model_selection import GridSearchCV

clf = xgb.XGBClassifier()
parameters = {
#      "eta"    : [0.05, 0.10, 0.15, 0.20, 0.25, 0.30 ] ,
     "eta"    : [0.05, 0.10] ,
     "max_depth"        : [ 3, 4, 5, 6, 8, 10, 12, 15],
     "min_child_weight" : [ 1, 3, 5, 7 ],
     "gamma"            : [ 0.0, 0.1, 0.2 , 0.3, 0.4 ],
     "colsample_bytree" : [ 0.3, 0.4, 0.5 , 0.7 ]
     }

grid = GridSearchCV(clf,
                    parameters, n_jobs=4,
                    scoring="neg_log_loss",
                    cv=3)

grid.fit(X_train, Y_train)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-21-9acd5fe4f483> in <module>
#      16                     cv=3)
#      17
# ---> 18 grid.fit(X_train, Y_train)
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py in fit(self, X, y, groups, **fit_params)
#     708                 return results
#     709
# --> 710             self._run_search(evaluate_candidates)
#     711
#     712         # For multi-metric evaluation, store the best_index_, best_params_ and
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py in _run_search(self, evaluate_candidates)
#    1149     def _run_search(self, evaluate_candidates):
#    1150         """Search all candidates in param_grid"""
# -> 1151         evaluate_candidates(ParameterGrid(self.param_grid))
#    1152
#    1153
#
# ...

# %%
grid_predict = grid.predict(x_test)

# %%
grid_prediction_output = pd.DataFrame(test['tripid'])

# %%
grid_prediction_output['prediction']= grid_predict

# %%
grid_prediction_output.to_csv('gridsearch.csv', encoding='utf-8', index=False)
